# %%
#import ROOT
import uproot
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as LogNorm
import matplotlib.ticker as ticker
import math

# %%
file_path = "../trees/rho_skim_10.2.root"
tree_name = "ePi"
M_rho = []
Mx_2pi = []

with uproot.open(file_path) as file:
    tree = file[tree_name]
    x_branch = 'M_rho'
    y_branch = 'Mx_2pi'
    M_rho = tree.arrays()[x_branch]
    Mx_2pi = tree.arrays()[y_branch]
    print(M_rho)
    # Create the 2D histogram
# Out:
# [0.459, 0.63, 0.778, 0.637, 0.68, 0.904, ..., 0.816, 0.397, 0.305, 0.353, 0.934]

# %%
plt.hist2d( M_rho, Mx_2pi, bins = (100, 100))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.hist2d( M_rho, Mx_2pi, bins = (100, 100))
#
# File ~/Documents/Work/sidis_analysis_suite/plotting/env/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Documents/Work/sidis_analysis_suite/plotting/env/lib/python3.13/site-packages/matplotlib/pyplot.py:3528, in hist2d(x, y, bins, range, density, weights, cmin, cmax, data, **kwargs)
#    3514 @_copy_docstring_and_deprecators(Axes.hist2d)
#    3515 def hist2d(
#    3516     x: ArrayLike,
#    (...)
#    3526     **kwargs,
#    3527 ) -> tuple[np.ndarray, np.ndarray, np.ndarray, QuadMesh]:
# -> 3528     __ret = gca().hist2d(
#    3529         x,
#    3530         y,
#    3531         bins=bins,
#    3532         range=range,
#    3533         density=density,
#    3534         weights=weights,
#    3535         cmin=cmin,
#    3536         cmax=cmax,
#    3537         **({"data": data} if data is not None else {}),
#    3538         **kwargs,
#    3539     )
#    3540     sci(__ret[-1])
#    3541     return __ret
#
# File ~/Documents/Work/sidis_analysis_suite/plotting/env/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Documents/Work/sidis_analysis_suite/plotting/env/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/Documents/Work/sidis_analysis_suite/plotting/env/lib/python3.13/site-packages/matplotlib/axes/_axes.py:7481, in Axes.hist2d(self, x, y, bins, range, density, weights, cmin, cmax, **kwargs)
#    7478 if cmax is not None:
#    7479     h[h > cmax] = None
# -> 7481 pc = self.pcolormesh(xedges, yedges, h.T, **kwargs)
#    7482 self.set_xlim(xedges[0], xedges[-1])
#    7483 self.set_ylim(yedges[0], yedges[-1])
#
# File ~/Documents/Work/sidis_analysis_suite/plotting/env/lib/python3.13/site-packages/awkward/highlevel.py:1289, in Array.__getattr__(self, where)
#    1284         raise AttributeError(
#    1285             f"while trying to get field {where!r}, an exception "
#    1286             f"occurred:\n{type(err)}: {err!s}"
#    1287         ) from err
#    1288 else:
# -> 1289     raise AttributeError(f"no field named {where!r}")
#
# AttributeError: no field named 'T'
